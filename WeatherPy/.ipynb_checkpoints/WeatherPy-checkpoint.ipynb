# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from pprint import pprint
# Import API key
from api_keys import weather_api_key
from datetime import date

today = date.today()

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url="http://api.openweathermap.org/data/2.5/weather?"
#units: imperial or metric
units="imperial"
query_url=f"{url}appid={weather_api_key}&units={units}&q="

#empty arrays will store weather data for cities
temp=[]
latitude=[]
longitude=[]
clouds=[]
humid=[]
wind=[]

#error handling for cities that do not have weather data
for city in cities:
    try:
        response=requests.get(query_url+city).json()
        #check the json format for calls
        #pprint(response)
        temp.append(response['main']['temp'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        clouds.append(response['clouds']['all'])
        humid.append(response['main']['humidity'])
        wind.append(response['wind']['speed'])
        print(f"The temp in {cities.index(city)}:{city} is {response['main']['temp']}. Lat: {response['coord']['lat']}. Long: {response['coord']['lon']}")
    except: 
        temp.append('NaN')
        latitude.append('NaN')
        longitude.append('NaN')
        clouds.append('NaN')
        humid.append('NaN')
        wind.append('NaN')
        print (f"{cities.index(city)}:{city} not found.")
        
#check list lengths to make sure they all match prior to joining in dataframe (part of early troubleshooting)
print(f"Cities: {len(cities)}")
print(f"Lats: {len(latitude)}")
print(f"Longs: {len(longitude)}")
print(f"Temp: {len(temp)}")
print(f"clouds: {len(clouds)}")
print(f"humid: {len(humid)}")
print(f"wind: {len(wind)}")
# Out:
# The temp in 0:carnarvon is 53.6. Lat: -24.87. Long: 113.63
# 1:burica not found.
# The temp in 2:eisiskes is 63.19. Lat: 54.17. Long: 25
# The temp in 3:rikitea is 68.23. Lat: -23.12. Long: -134.97
# The temp in 4:soavinandriana is 43.18. Lat: -19.17. Long: 46.73
# The temp in 5:tazovskiy is 48.94. Lat: 67.47. Long: 78.7
# The temp in 6:quang ngai is 74.71. Lat: 15.12. Long: 108.8
# 7:taolanaro not found.
# The temp in 8:kapaa is 81.61. Lat: 22.08. Long: -159.32
# The temp in 9:atuona is 80.06. Lat: -9.8. Long: -139.03
# The temp in 10:bengkulu is 76.3. Lat: -3.8. Long: 102.27
# The temp in 11:plettenberg bay is 59.68. Lat: -34.05. Long: 23.37
# The temp in 12:suntar is 61.23. Lat: 62.14. Long: 117.63
# The temp in 13:wukari is 74.12. Lat: 7.85. Long: 9.78
# 14:fort saint john not found.
# The temp in 15:lebu is 51.64. Lat: -37.62. Long: -73.65
# The temp in 16:norman wells is 62.6. Lat: 65.28. Long: -126.83
# The temp in 17:dikson is 39.99. Lat: 73.51. Long: 80.55
# The temp in 18:busselton is 48.29. Lat: -33.65. Long: 115.33
# The temp in 19:faanui is 77.4. Lat: -16.48. Long: -151.75
# The temp in 20:jijiga is 64.13. Lat: 9.35. Long: 42.8
# The temp in 21:bilibino is 68.58. Lat: 68.05. Long: 166.44
# 22:dibaya not found.
# 23:mys shmidta not found.
# The temp in 24:whitianga is 59. Lat: -36.83. Long: 175.7
# The temp in 25:kusu is 76.6. Lat: 33.28. Long: 131.15
# The temp in 26:hobyo is 77.49. Lat: 5.35. Long: 48.53
# The temp in 27:sao joao da barra is 73.4. Lat: -21.64. Long: -41.05
# The temp in 529:massakory is 80.37. Lat: 13. Long: 15.73
# The temp in 530:russell is 89.42. Lat: 32.35. Long: -85.2
# The temp in 531:ghanzi is 48.42. Lat: -21.57. Long: 21.78
# The temp in 532:capao da canoa is 66.69. Lat: -29.75. Long: -50.01
# The temp in 533:quelimane is 65.14. Lat: -17.88. Long: 36.89
# The temp in 534:sibu is 75.07. Lat: 2.3. Long: 111.82
# The temp in 535:natal is 73.4. Lat: -5.79. Long: -35.21
# The temp in 536:gornopravdinsk is 51.1. Lat: 60.05. Long: 69.9
# The temp in 537:naze is 80.69. Lat: 28.37. Long: 129.48
# 538:karkaralinsk not found.
# The temp in 539:potiskum is 77.97. Lat: 11.71. Long: 11.07
# The temp in 540:bathsheba is 82.4. Lat: 13.22. Long: -59.52
# The temp in 541:ormara is 85.23. Lat: 25.21. Long: 64.64
# The temp in 542:la rioja is 75.2. Lat: 42.25. Long: -2.5
# The temp in 543:abbeville is 54.48. Lat: 50.1. Long: 1.83
# The temp in 544:uhlove is 71.69. Lat: 44.82. Long: 33.6
# The temp in 545:aksu is 70.77. Lat: 41.12. Long: 80.26
# The temp in 546:cockburn town is 87.8. Lat: 21.46. Long: -71.14
# The temp in 547:grand-santi is 75.25. Lat: 4.25. Long: -54.38
# 548:shchelyayur not found.
# The temp in 549:great bend is 87.8. Lat: 38.36. Long: -98.76
# The temp in 550:rapid valley is 67.62. Lat: 44.06. Long: -103.15
# The temp in 551:ergani is 79.59. Lat: 38.27. Long: 39.76
# 552:mrirt not found.
# The temp in 553:nanakuli is 86.61. Lat: 21.39. Long: -158.15
# 554:umzimvubu not found.
# The temp in 555:snezhnogorsk is 68. Lat: 69.19. Long: 33.25
# The temp in 556:gazojak is 84.6. Lat: 41.19. Long: 61.4
# The temp in 557:batagay-alyta is 67.21. Lat: 67.8. Long: 130.41
# The temp in 558:vitim is 52.09. Lat: 59.45. Long: 112.56
# The temp in 559:agdas is 75.2. Lat: 40.65. Long: 47.48
# The temp in 560:arman is 63.07. Lat: 59.7. Long: 150.17
# The temp in 561:greytown is 49.96. Lat: -29.06. Long: 30.59
# The temp in 562:flin flon is 77. Lat: 54.77. Long: -101.86
# The temp in 563:xiongyue is 73.08. Lat: 40.18. Long: 122.12
# 564:satitoa not found.
# The temp in 565:amberieu-en-bugey is 78.37. Lat: 45.96. Long: 5.34
# The temp in 566:santa isabel is 65.3. Lat: -23.32. Long: -46.22
# 567:halalo not found.
# The temp in 568:balkhash is 74.17. Lat: 46.84. Long: 74.98
# The temp in 569:aasiaat is 45.34. Lat: 68.71. Long: -52.87
# The temp in 570:lizzano is 75. Lat: 40.39. Long: 17.45
# The temp in 571:porvoo is 58.39. Lat: 60.39. Long: 25.67
# The temp in 572:wanaka is 42.42. Lat: -44.7. Long: 169.15
# The temp in 573:poum is 70.36. Lat: -20.23. Long: 164.02
# The temp in 574:atambua is 66.67. Lat: -9.11. Long: 124.89
# The temp in 575:ishigaki is 82.4. Lat: 24.34. Long: 124.16
# The temp in 576:aljezur is 81.36. Lat: 37.32. Long: -8.8
# The temp in 577:mandan is 72.09. Lat: 46.83. Long: -100.89
# The temp in 578:paita is 64.67. Lat: -5.09. Long: -81.11
# The temp in 579:shanhetun is 65.68. Lat: 44.7. Long: 127.2
# The temp in 580:cayenne is 80.6. Lat: 4.93. Long: -52.33
# The temp in 581:vuktyl is 53.51. Lat: 63.86. Long: 57.31
# The temp in 582:leshukonskoye is 58.03. Lat: 64.9. Long: 45.76
# The temp in 583:alofi is 82.4. Lat: -19.06. Long: -169.92
# The temp in 584:yulara is 48.2. Lat: -25.24. Long: 130.99
# The temp in 585:doka is 72.05. Lat: 13.52. Long: 35.77
# The temp in 586:correntina is 71.19. Lat: -13.34. Long: -44.64
# The temp in 587:hit is 92.86. Lat: 33.64. Long: 42.83
# The temp in 588:ellisras is 47.52. Lat: -23.66. Long: 27.74
# The temp in 589:bilaspur is 84.04. Lat: 22.08. Long: 82.15
# The temp in 590:jurm is 64.89. Lat: 36.86. Long: 70.83
# The temp in 591:dharchula is 68.34. Lat: 29.85. Long: 80.53
# 592:jiddah not found.
# The temp in 593:hotonj is 59. Lat: 43.89. Long: 18.37
# The temp in 594:spring hill is 88.99. Lat: 28.48. Long: -82.53
# The temp in 595:muskegon is 74.75. Lat: 43.3. Long: -86.13
# The temp in 596:kiruna is 53.6. Lat: 67.86. Long: 20.23
# The temp in 597:mantenopolis is 66.06. Lat: -18.86. Long: -41.12
# The temp in 598:miquelon is 60.4. Lat: 47.1. Long: -56.38
# The temp in 599:birobidzhan is 65.93. Lat: 48.8. Long: 132.95
# 600:villa vazquez not found.
# 601:babanusah not found.
# The temp in 602:huilong is 78.58. Lat: 31.81. Long: 121.66
# The temp in 603:chandbali is 83.08. Lat: 20.78. Long: 86.77
# The temp in 604:vrede is 42.55. Lat: -27.43. Long: 29.17
# The temp in 605:severo-yeniseyskiy is 49.93. Lat: 60.37. Long: 93.04
# The temp in 606:kichera is 52.12. Lat: 55.94. Long: 110.1
# The temp in 607:porbandar is 84.27. Lat: 21.64. Long: 69.61
# The temp in 608:lixourion is 71.11. Lat: 38.2. Long: 20.43
# The temp in 609:luanda is 69.8. Lat: -8.84. Long: 13.23
# The temp in 610:panlaitan is 83.39. Lat: 12.12. Long: 119.85
# The temp in 611:terrace bay is 60.8. Lat: 48.78. Long: -87.1
# The temp in 612:ribeira grande is 69.84. Lat: 38.52. Long: -28.7
# The temp in 613:muli is 83.52. Lat: 2.92. Long: 73.57
# The temp in 614:hami is 85.05. Lat: 42.8. Long: 93.45
# The temp in 615:vostok is 59.34. Lat: 46.49. Long: 135.88
# The temp in 616:denpasar is 78.8. Lat: -8.65. Long: 115.22
# The temp in 617:real is 79.56. Lat: 14.66. Long: 121.6
# The temp in 618:haines junction is 67.23. Lat: 60.75. Long: -137.51
# The temp in 619:bandar-e lengeh is 93.2. Lat: 26.56. Long: 54.88
# The temp in 620:puerto colombia is 86. Lat: 10.99. Long: -74.95
# The temp in 621:plum is 88.09. Lat: 40.5. Long: -79.75
# The temp in 622:praia da vitoria is 71.6. Lat: 38.73. Long: -27.07
# The temp in 623:iralaya is 87.8. Lat: 15. Long: -83.23
# The temp in 624:kargil is 54.12. Lat: 34.57. Long: 76.1
# 625:saleaula not found.
# Cities: 626
# Lats: 626
# Longs: 626
# Temp: 626
# clouds: 626
# humid: 626
# wind: 626

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#combine weather data to dictionary and array
weather_dict={
    "city":cities,
    "lat":latitude,
    "long":longitude,
    "temp":temp,
    "clouds":clouds,
    "humid":humid,
    "wind":wind
}
weather_data=pd.DataFrame(weather_dict)
weather_data.head(10)
# Out:
#              city    lat    long   temp clouds humid   wind
# 0       carnarvon -24.87  113.63   53.6      0    76   6.93
# 1          burica    NaN     NaN    NaN    NaN   NaN    NaN
# 2        eisiskes  54.17      25  63.19     75    88   8.05
# 3         rikitea -23.12 -134.97  68.23     92    59  12.44
# 4  soavinandriana -19.17   46.73  43.18      2    90   7.27
# 5       tazovskiy  67.47    78.7  48.94     92    79   12.1
# 6      quang ngai  15.12   108.8  74.71     85    88   3.96
# 7       taolanaro    NaN     NaN    NaN    NaN   NaN    NaN
# 8           kapaa  22.08 -159.32  81.61     90    69  14.99
# 9          atuona   -9.8 -139.03  80.06     42    77   15.9

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#check for cities with out of range humidity: gt 100%

weather_data['humidity'] = pd.to_numeric(weather_data['humid'], errors='coerce')
weather_data['humidity'].describe()
#No places with humidity >100
#humid_df=weather_data.loc[weather_data["humidity"]>100]
# Out:
# count    573.000000
# mean      71.560209
# std       19.831333
# min        3.000000
# 25%       62.000000
# 50%       76.000000
# 75%       87.000000
# max      100.000000
# Name: humidity, dtype: float64

# %%
#check cloudiness for out of range: Gt 100%
weather_data['clouds'] = pd.to_numeric(weather_data['clouds'], errors='coerce')
weather_data['clouds'].describe()
# Out:
# count    573.000000
# mean      48.816754
# std       38.231759
# min        0.000000
# 25%        7.000000
# 50%       44.000000
# 75%       87.000000
# max      100.000000
# Name: clouds, dtype: float64

# %%
#  Get the indices of cities that have humidity over 100%.
#No cities with humidity over 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#N/A No cities with humidity >100

# %%
# Extract relevant fields from the data frame
# Export the City_Data into a csv
weather_data.to_csv('weather.csv',index=False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#define a function for creating scatter plots for various weather attributes by temperature
#input (data frame, x value, y value, title of plot)
#create scatter plot and export to .png
def my_plot(mydf, x, y, title):
    plt.scatter(mydf[x],mydf[y], marker="o")
    new_title=title+" "+str(today)
    plt.title(new_title)
    plt.ylabel(y)
    plt.xlabel(x)
    plt.grid(True)
    filename=title+"_"+str(today)+".png"
    plt.savefig(filename, format='png')
    plt.show()

my_plot(weather_data,'lat','temp','Latitude vs Temperature')

# %%
## This plot is latitude versus temperature. Temperatures peak near the equator (lattitude=0) and drop as we move futher away from the equator. 
## There are more data points in the Northern hemisphere than the Southern hemisphere.

# %% [markdown]
# ## Linear Regression

# %%
  
my_plot(weather_data,'lat','humidity','Latitude vs Humidity')

# %%
##There does not appear to be an obvious relationship between lattitude and humidity.

# %%
my_plot(weather_data,'lat','clouds','Latitude vs Cloudiness')

# %%
##Cloudiness does also not appear to be related to latitude, but it does appear to be measured common break points like 20%, 
##40%,75%, and 100%

# %%
my_plot(weather_data,'lat','wind','Latitude vs Wind Speed')

# %%
#Wind speed and latitude do not appear to be strongly correlated.

# %%
# Create Northern and Southern Hemisphere DataFrames
weather_data['lat'] = pd.to_numeric(weather_data['lat'], errors='coerce')
weather_data['lat'].describe()

south_data=weather_data.loc[weather_data['lat']<0]
north_data=weather_data.loc[weather_data['lat']>0]

# %%
# Create a function to create Linear Regression plots
#input (data frame, x value, y value, title of plot)
#save output to a .png file

def my_reg(mydf, x, y, title):
    x_values=pd.to_numeric(mydf[x])
    y_values=pd.to_numeric(mydf[y])
    plt.scatter(x_values, y_values)
    plt.xlabel(x)
    plt.ylabel(y)
    new_title=title+" "+str(today)
    plt.title(new_title)
    (slope, intercept, rvalue, pvalue, stderr)=stats.linregress(x_values,y_values)
    regress_values=x_values*slope+intercept
    plt.plot(x_values, regress_values)
    line_eq="y ="+str(round(slope,2))+ "x +"+str(round(intercept,2))
    print(f"The line equation is: {line_eq}.")
    print(f"The r-squared is: {rvalue**2}")
    filename=title+"_"+str(today)+".png"
    plt.savefig(filename, format='png')
    plt.show()
my_reg(north_data,'lat','temp','Temp vs Lat North')    
my_reg(south_data,'lat','temp','Temp vs Lat South')
# Out:
# The line equation is: y =-0.45x +88.0.
# The r-squared is: 0.4552813539207605
# The line equation is: y =0.79x +79.79.
# The r-squared is: 0.6156021100575796

# %%
#In the southern hemisphere, the temperature increases as latitude increases. The northern hemisphere, the temperature 
#decreases as latitude increases. The relationship between latitude and temperature is stronger in the Southern hemisphere
#than in the Northern hemisphere (r2 of .615 versus r2 of .455). In either case, there are some temperature plots far off of 
#fit line.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
my_reg(north_data,'lat','humidity','Humidity vs Lat North')    
my_reg(south_data,'lat','humidity','Humidity vs Lat South')
# Out:
# The line equation is: y =-0.01x +71.2.
# The r-squared is: 0.00010064122012249883
# The line equation is: y =-0.1x +71.17.
# The r-squared is: 0.005771815897694977

# %%
#As predicted from the scatterplot, there is no significant relationship between latitude and humidity in either hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
my_reg(north_data,'lat','clouds','Cloudiness vs Lat North')    
my_reg(south_data,'lat','clouds','Cloudiness vs Lat South')
# Out:
# The line equation is: y =-0.02x +51.87.
# The r-squared is: 0.00011978353420949011
# The line equation is: y =-0.59x +30.86.
# The r-squared is: 0.042075582662243524

# %%
#Cloudiness does not appear to be correlated with lattitude. A slight bit more of the variation in cloudiness is associated 
#with lattitude in the Southern hemisphere, but the r2 is so low (<.05), it is not notable.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
my_reg(north_data,'lat','wind','Wind Speed vs Lat North')    
my_reg(south_data,'lat','wind','Wind Speed vs Lat South')
# Out:
# The line equation is: y =-0.03x +8.92.
# The r-squared is: 0.01844407200569892
# The line equation is: y =0.04x +7.81.
# The r-squared is: 0.011190882954984036

# %%
##There is little relationship between wind speed and latitude in either hemisphere.
